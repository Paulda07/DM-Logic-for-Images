# %%
#importing the required module 
import matplotlib.pyplot as plt 
  
# x axis values 
x = [1,2,3] 
# corresponding y axis values 
y = [2,4,1] 
  
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('My first graph!') 
  
# function to show the plot 
plt.show()

# %%
plt.show()

# %%
plt.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a36c833e282e> in <module>()
# ----> 1 plt.display()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'display'

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
fig_size = plt.rcParams["figure.figsize"]
print( "Current size:", fig_size)
fig_size[0] = 13
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size
x= [0.9501,0.2311,0.6068,0.4860,0.8913,0.7621,0.4565,0.0185,0.8214,0.3480]
y= [0.6154,0.0598,0.9218,0.7382,0.1763,0.4057,0.2242,0.9169,0.6111,0.8936]
#plt.plot(x,y)
plt.scatter(x,y)
for xy in zip(x, y):                                       
    ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data')
plt.plot( [0.486, 0.486], [0,1.0] )

plt.show()
#plt.grid()
plt.show()
# Out:
# Current size: [13.0, 12.0]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

numImages = int (100/2)
fig = plt.figure(figsize=(7,7))
imgData = np.zeros(shape=(numImages,36963))
# imgData
# import os

# curpath = os.path.abspath(os.curdir)
# packet_file = "digit1_1.jpg"
# print ("Current path is: %s",curpath)
# print ("Trying to open: %s", os.path.join(curpath, packet_file))

# image = mpimg.imread(packet_file)

# image 
# filename = 'digit1_1'+'.jpg'
# image = mpimg.imread(filename)
# image
for j in range(1,3):
    for i in range(1,numImages+1):
        filename = 'digit'+str(j)+'_'+str(i)+'.jpg'
        img = mpimg.imread(filename)
        ax = fig.add_subplot(10,10, ((j-1)*50)+i)
        plt.imshow(img)
        plt.axis('off')
        ax.set_title(str(i))
#     imgData[i-1] = np.array(img.flatten()).reshape(1,img.shape[0]*img.shape[1]*img.shape[2])

# %%
img = imread(‘digit1_1.png’)
# Out:
#   File "<ipython-input-21-750813ca8b3e>", line 1
#     img = imread(‘digit1_1.png’)
#                          ^
# SyntaxError: invalid character in identifier

# %%
import cv2

# %%
import numpy as np

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c8ec22b3e787> in <module>()
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install cv2
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install cv2
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/
